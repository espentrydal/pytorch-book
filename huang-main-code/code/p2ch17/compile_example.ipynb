# %%
import torch
import torch.nn as nn
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
class ConditionalModel(nn.Module):
    def __init__(self):
        super(ConditionalModel, self).__init__()
        self.fc1 = nn.Linear(10, 5)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(10, 3)
    def forward(self, x):
        if x.sum() > 0:
            x = self.fc1(x)
        else:
            x = self.fc2(x)
        x = self.relu(x)
        return x
model = ConditionalModel()
model = model.to(device)
model.eval()
# Out:
# ConditionalModel(
#   (fc1): Linear(in_features=10, out_features=5, bias=True)
#   (relu): ReLU()
#   (fc2): Linear(in_features=10, out_features=3, bias=True)
# )

# %%
example_input = torch.randn(5, 10)
torch.export.export(model, (example_input,))
# Out:
# ---------------------------------------------------------------------------
# UserError                                 Traceback (most recent call last)
# Cell In[60], line 2
#       1 example_input = torch.randn(5, 10)
# ----> 2 torch.export.export(model, (example_input,))
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/export/__init__.py:368, in export(mod, args, kwargs, dynamic_shapes, strict, preserve_module_call_signature)
#     362 if isinstance(mod, torch.jit.ScriptModule):
#     363     raise ValueError(
#     364         "Exporting a ScriptModule is not supported. "
#     365         "Maybe try converting your ScriptModule to an ExportedProgram "
#     366         "using `TS2EPConverter(mod, args, kwargs).convert()` instead."
#     367     )
# --> 368 return _export(
#     369     mod,
#     370     args,
#     371     kwargs,
#     372     dynamic_shapes,
#     373     strict=strict,
#     374     preserve_module_call_signature=preserve_module_call_signature,
#     375     pre_dispatch=True,
#     376 )
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/export/_trace.py:1035, in _log_export_wrapper.<locals>.wrapper(*args, **kwargs)
#    1028     else:
#    1029         log_export_usage(
#    1030             event="export.error.unclassified",
#    1031             type=error_type,
#    1032             message=str(e),
#    1033             flags=_EXPORT_FLAGS,
#    1034         )
# -> 1035     raise e
#    1036 finally:
#    1037     _EXPORT_FLAGS = None
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/export/_trace.py:1008, in _log_export_wrapper.<locals>.wrapper(*args, **kwargs)
#    1006 try:
#    1007     start = time.time()
# -> 1008     ep = fn(*args, **kwargs)
#    1009     end = time.time()
#    1010     log_export_usage(
#    1011         event="export.time",
#    1012         metrics=end - start,
#    1013         flags=_EXPORT_FLAGS,
#    1014         **get_ep_stats(ep),
#    1015     )
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/export/exported_program.py:128, in _disable_prexisiting_fake_mode.<locals>.wrapper(*args, **kwargs)
#     125 @functools.wraps(fn)
#     126 def wrapper(*args, **kwargs):
#     127     with unset_fake_temporarily():
# --> 128         return fn(*args, **kwargs)
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/export/_trace.py:1970, in _export(mod, args, kwargs, dynamic_shapes, strict, preserve_module_call_signature, pre_dispatch, allow_complex_guards_as_runtime_asserts, _is_torch_jit_trace)
#    1962 # NOTE Export training IR rollout
#    1963 # Old export calls export._trace(pre_dispatch=True)
#    1964 # and there are still lot of internal/OSS callsites that
#    (...)
#    1967 # export_training_ir_rollout_check returns True in OSS
#    1968 # while internally it returns False UNLESS otherwise specified.
#    1969 if pre_dispatch and export_training_ir_rollout_check():
# -> 1970     return _export_for_training(
#    1971         mod,
#    1972         args,
#    1973         kwargs,
#    1974         dynamic_shapes,
#    1975         strict=strict,
#    1976         preserve_module_call_signature=preserve_module_call_signature,
#    1977     )
#    1979 (
#    1980     args,
#    1981     kwargs,
#    (...)
#    1984     dynamic_shapes,
#    1985 ) = _process_export_inputs(mod, args, kwargs, dynamic_shapes)
#    1987 # Call the appropriate export function based on the strictness of tracing.
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/export/_trace.py:1035, in _log_export_wrapper.<locals>.wrapper(*args, **kwargs)
#    1028     else:
#    1029         log_export_usage(
#    1030             event="export.error.unclassified",
#    1031             type=error_type,
#    1032             message=str(e),
#    1033             flags=_EXPORT_FLAGS,
#    1034         )
# -> 1035     raise e
#    1036 finally:
#    1037     _EXPORT_FLAGS = None
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/export/_trace.py:1008, in _log_export_wrapper.<locals>.wrapper(*args, **kwargs)
#    1006 try:
#    1007     start = time.time()
# -> 1008     ep = fn(*args, **kwargs)
#    1009     end = time.time()
#    1010     log_export_usage(
#    1011         event="export.time",
#    1012         metrics=end - start,
#    1013         flags=_EXPORT_FLAGS,
#    1014         **get_ep_stats(ep),
#    1015     )
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/export/exported_program.py:128, in _disable_prexisiting_fake_mode.<locals>.wrapper(*args, **kwargs)
#     125 @functools.wraps(fn)
#     126 def wrapper(*args, **kwargs):
#     127     with unset_fake_temporarily():
# --> 128         return fn(*args, **kwargs)
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/export/_trace.py:1834, in _export_for_training(mod, args, kwargs, dynamic_shapes, strict, preserve_module_call_signature)
#    1815 (
#    1816     args,
#    1817     kwargs,
#    (...)
#    1820     dynamic_shapes,
#    1821 ) = _process_export_inputs(mod, args, kwargs, dynamic_shapes)
#    1823 export_func = (
#    1824     functools.partial(
#    1825         _strict_export_lower_to_aten_ir,
#    (...)
#    1832     )
#    1833 )
# -> 1834 export_artifact = export_func(  # type: ignore[operator]
#    1835     mod=mod,
#    1836     args=args,
#    1837     kwargs=kwargs,
#    1838     dynamic_shapes=dynamic_shapes,
#    1839     preserve_module_call_signature=preserve_module_call_signature,
#    1840     pre_dispatch=False,
#    1841     original_state_dict=original_state_dict,
#    1842     orig_in_spec=orig_in_spec,
#    1843     allow_complex_guards_as_runtime_asserts=False,
#    1844     _is_torch_jit_trace=False,
#    1845 )
#    1847 export_graph_signature = export_artifact.aten.sig
#    1849 forward_arg_names = _get_forward_arg_names(mod, args, kwargs)
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/export/_trace.py:1283, in _strict_export_lower_to_aten_ir(mod, args, kwargs, dynamic_shapes, preserve_module_call_signature, pre_dispatch, original_state_dict, orig_in_spec, allow_complex_guards_as_runtime_asserts, _is_torch_jit_trace, lower_to_aten_callback)
#    1270 def _strict_export_lower_to_aten_ir(
#    1271     mod: torch.nn.Module,
#    1272     args: Tuple[Any, ...],
#    (...)
#    1281     lower_to_aten_callback: Callable,
#    1282 ) -> ExportArtifact:
# -> 1283     gm_torch_level = _export_to_torch_ir(
#    1284         mod,
#    1285         args,
#    1286         kwargs,
#    1287         dynamic_shapes,
#    1288         preserve_module_call_signature=preserve_module_call_signature,
#    1289         restore_fqn=False,  # don't need to restore because we will do it later
#    1290         allow_complex_guards_as_runtime_asserts=allow_complex_guards_as_runtime_asserts,
#    1291         _log_export_usage=False,
#    1292     )
#    1294     # We detect the fake_mode by looking at gm_torch_level's placeholders, this is the fake_mode created in dynamo.
#    1295     (
#    1296         fake_args,
#    1297         fake_kwargs,
#    1298         dynamo_fake_mode,
#    1299     ) = _extract_fake_inputs(gm_torch_level, args, kwargs)
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/export/_trace.py:662, in _export_to_torch_ir(f, args, kwargs, dynamic_shapes, preserve_module_call_signature, disable_constraint_solver, allow_complex_guards_as_runtime_asserts, restore_fqn, _log_export_usage, same_signature)
#     658     module_call_specs: Dict[str, Dict[str, pytree.TreeSpec]] = {}
#     659     with _wrap_submodules(
#     660         f, preserve_module_call_signature, module_call_specs
#     661     ), _ignore_backend_decomps():
# --> 662         gm_torch_level, _ = torch._dynamo.export(
#     663             f,
#     664             dynamic_shapes=dynamic_shapes,  # type: ignore[arg-type]
#     665             assume_static_by_default=True,
#     666             tracing_mode="symbolic",
#     667             disable_constraint_solver=disable_constraint_solver,
#     668             # currently the following 2 flags are tied together for export purposes,
#     669             # but untangle for sake of dynamo export api
#     670             prefer_deferred_runtime_asserts_over_guards=True,
#     671             allow_complex_guards_as_runtime_asserts=allow_complex_guards_as_runtime_asserts,
#     672             _log_export_usage=_log_export_usage,
#     673             same_signature=same_signature,
#     674         )(
#     675             *args,
#     676             **kwargs,
#     677         )
#     678 except (ConstraintViolationError, ValueRangeError) as e:
#     679     raise UserError(UserErrorType.CONSTRAINT_VIOLATION, str(e))  # noqa: B904
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:1569, in export.<locals>.inner(*args, **kwargs)
#    1567 # TODO(voz): We may have instances of `f` that mutate inputs, we should track sideeffects and reject.
#    1568 try:
# -> 1569     result_traced = opt_f(*args, **kwargs)
#    1570 except ConstraintViolationError as e:
#    1571     constraint_violation_error = e
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:574, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     569 saved_dynamic_layer_stack_depth = (
#     570     torch._C._functorch.get_dynamic_layer_stack_depth()
#     571 )
#     573 try:
# --> 574     return fn(*args, **kwargs)
#     575 finally:
#     576     # Restore the dynamic layer stack depth if necessary.
#     577     torch._C._functorch.pop_dynamic_layer_stack_and_undo_to_depth(
#     578         saved_dynamic_layer_stack_depth
#     579     )
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/_dynamo/convert_frame.py:1380, in CatchErrorsWrapper.__call__(self, frame, cache_entry, frame_state)
#    1374             return hijacked_callback(
#    1375                 frame, cache_entry, self.hooks, frame_state
#    1376             )
#    1378 with compile_lock, _disable_current_modes():
#    1379     # skip=1: skip this frame
# -> 1380     return self._torchdynamo_orig_callable(
#    1381         frame, cache_entry, self.hooks, frame_state, skip=1
#    1382     )
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/_dynamo/convert_frame.py:547, in ConvertFrameAssert.__call__(self, frame, cache_entry, hooks, frame_state, skip)
#     544     dynamo_tls.traced_frame_infos.append(info)
#     546 with compile_context(CompileContext(compile_id)):
# --> 547     return _compile(
#     548         frame.f_code,
#     549         frame.f_globals,
#     550         frame.f_locals,
#     551         frame.f_builtins,
#     552         frame.closure,
#     553         self._torchdynamo_orig_callable,
#     554         self._one_graph,
#     555         self._export,
#     556         self._export_constraints,
#     557         hooks,
#     558         cache_entry,
#     559         cache_size,
#     560         frame,
#     561         frame_state=frame_state,
#     562         compile_id=compile_id,
#     563         skip=skip + 1,
#     564     )
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/_dynamo/convert_frame.py:986, in _compile(code, globals, locals, builtins, closure, compiler_fn, one_graph, export, export_constraints, hooks, cache_entry, cache_size, frame, frame_state, compile_id, skip)
#     984 guarded_code = None
#     985 try:
# --> 986     guarded_code = compile_inner(code, one_graph, hooks, transform)
#     988     # NB: We only put_code_state in success case.  Success case here
#     989     # does include graph breaks; specifically, if a graph break still
#     990     # resulted in a partially compiled graph, we WILL return here.  An
#    (...)
#     995     # to upload for graph break though, because this can prevent
#     996     # extra graph break compilations.)
#     997     put_code_state()
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/_dynamo/convert_frame.py:715, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     713     stack.enter_context(torch._dynamo.callback_handler.install_callbacks())
#     714     stack.enter_context(CompileTimeInstructionCounter.record())
# --> 715     return _compile_inner(code, one_graph, hooks, transform)
#     717 return None
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/_utils_internal.py:95, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#      92     kwargs["skip"] = skip + 1
#      94 if not StrobelightCompileTimeProfiler.enabled:
# ---> 95     return function(*args, **kwargs)
#      97 return StrobelightCompileTimeProfiler.profile_compile_time(
#      98     function, phase_name, *args, **kwargs
#      99 )
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/_dynamo/convert_frame.py:750, in _compile.<locals>._compile_inner(code, one_graph, hooks, transform)
#     748 CompileContext.get().attempt = attempt
#     749 try:
# --> 750     out_code = transform_code_object(code, transform)
#     751     break
#     752 except exc.RestartAnalysis as e:
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/_dynamo/bytecode_transformation.py:1361, in transform_code_object(code, transformations, safe)
#    1358 instructions = cleaned_instructions(code, safe)
#    1359 propagate_line_nums(instructions)
# -> 1361 transformations(instructions, code_options)
#    1362 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/_dynamo/convert_frame.py:231, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     229 exit_stack.enter_context(torch_function_mode_stack_state_mgr)
#     230 try:
# --> 231     return fn(*args, **kwargs)
#     232 finally:
#     233     cleanup.close()
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/_dynamo/convert_frame.py:662, in _compile.<locals>.transform(instructions, code_options)
#     660 try:
#     661     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 662         tracer.run()
#     663 except exc.UnspecializeRestartAnalysis:
#     664     speculation_log.clear()
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:2868, in InstructionTranslator.run(self)
#    2867 def run(self):
# -> 2868     super().run()
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:1052, in InstructionTranslatorBase.run(self)
#    1050 try:
#    1051     self.output.push_tx(self)
# -> 1052     while self.step():
#    1053         pass
#    1054 except TensorifyScalarRestartAnalysis:
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:962, in InstructionTranslatorBase.step(self)
#     959 self.update_block_stack(inst)
#     961 try:
# --> 962     self.dispatch_table[inst.opcode](self, inst)
#     963     return not self.output.should_exit
#     964 except TensorifyScalarRestartAnalysis:
#
# File ~/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/torch/_dynamo/symbolic_convert.py:640, in generic_jump.<locals>.inner(self, inst)
#     637         self.jump(inst)
#     638 else:
#     639     # TODO link the torch.cond doc later
# --> 640     raise exc.UserError(
#     641         exc.UserErrorType.DYNAMIC_CONTROL_FLOW,
#     642         "Dynamic control flow is not supported at the moment. Please use "
#     643         "functorch.experimental.control_flow.cond to explicitly capture the control flow.",
#     644         case_name="cond_operands",
#     645     )
#
# UserError: Dynamic control flow is not supported at the moment. Please use functorch.experimental.control_flow.cond to explicitly capture the control flow. For more information about this error, see: https://pytorch.org/docs/main/generated/exportdb/index.html#cond-operands
#
# from user code:
#    File "/var/folders/n1/ygzk0n895x15grwb5rm1ld300000gn/T/ipykernel_38275/3602047528.py", line 11, in forward
#     if x.sum() > 0:
#
# Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information

# %%
compiled_model = torch.compile(model)
compiled_model
# Out:
# OptimizedModule(
#   (_orig_mod): ConditionalModel(
#     (fc1): Linear(in_features=10, out_features=5, bias=True)
#     (relu): ReLU()
#     (fc2): Linear(in_features=10, out_features=3, bias=True)
#   )
# )

# %%
input_data = torch.randn(5, 10).to(device)
model_output = compiled_model(input_data)
model_output
# Out:
# tensor([[0.7042, 0.0000, 1.1878],
#         [0.0000, 1.1963, 0.0000],
#         [0.0000, 0.0000, 0.2733],
#         [0.0000, 1.1183, 0.2549],
#         [0.0000, 0.1559, 0.5826]], grad_fn=<CompiledFunctionBackward>)

# %%
input_data = torch.randn(5, 10).to(device)
output_original = model(input_data)
print("Output from original model:", output_original)
output_compiled = compiled_model(input_data)
print("Output from compiled model:", output_compiled)
# Out:
# Output from original model: tensor([[0.9162, 0.7815, 0.3962],
#         [0.6812, 0.3794, 0.0000],
#         [0.0000, 0.0000, 0.5863],
#         [0.0426, 0.4930, 0.3120],
#         [0.0000, 0.4797, 0.0000]], grad_fn=<ReluBackward0>)
# Output from compiled model: tensor([[0.9162, 0.7815, 0.3962],
#         [0.6812, 0.3794, 0.0000],
#         [0.0000, 0.0000, 0.5863],
#         [0.0426, 0.4930, 0.3120],
#         [0.0000, 0.4797, 0.0000]], grad_fn=<CompiledFunctionBackward>)

# %%
torch.compiler.list_backends()
# Out:
# /Users/howardhuang/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/onnxscript/converter.py:816: FutureWarning: 'onnxscript.values.Op.param_schemas' is deprecated in version 0.1 and will be removed in the future. Please use '.op_signature' instead.
#   param_schemas = callee.param_schemas()
# /Users/howardhuang/Documents/Mycode/DeepLearningWithPytorch-SecondEdition/.venv/lib/python3.12/site-packages/onnxscript/converter.py:816: FutureWarning: 'onnxscript.values.OnnxFunction.param_schemas' is deprecated in version 0.1 and will be removed in the future. Please use '.op_signature' instead.
#   param_schemas = callee.param_schemas()
# ['cudagraphs', 'inductor', 'onnxrt', 'openxla', 'tvm']

# %%
new_compiled_model = torch.compile(model)
new_compiled_model(input_data)
# Out:
# tensor([[0.9162, 0.7815, 0.3962],
#         [0.6812, 0.3794, 0.0000],
#         [0.0000, 0.0000, 0.5863],
#         [0.0426, 0.4930, 0.3120],
#         [0.0000, 0.4797, 0.0000]], grad_fn=<CompiledFunctionBackward>)
